# %% [markdown]
# # UrbanPulse AI
#
# # Image Detection using YOLOv8
#
# ## Objective
#
# Develop a Computer Vision model capable of detecting civic issues such as potholes and garbage from uploaded images.

# %%
# !pip install ultralytics roboflow
# Out:
# ...
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ------------------------------- -------- 1.0/1.3 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.3/1.3 MB 5.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    - -------------------------------------- 1.6/38.8 MB 7.6 MB/s eta 0:00:05
#    -- ------------------------------------- 2.9/38.8 MB 7.7 MB/s eta 0:00:05
#    ---- ----------------------------------- 4.2/38.8 MB 7.0 MB/s eta 0:00:05
#    ----- ---------------------------------- 5.5/38.8 MB 6.6 MB/s eta 0:00:06
#    -------- ------------------------------- 7.9/38.8 MB 7.5 MB/s eta 0:00:05
#    ---------- ----------------------------- 10.0/38.8 MB 8.0 MB/s eta 0:00:04
#    ------------ --------------------------- 12.1/38.8 MB 8.4 MB/s eta 0:00:04
#    -------------- ------------------------- 14.4/38.8 MB 8.7 MB/s eta 0:00:03
# ...

# %%
from ultralytics import YOLO

print("YOLO Imported Successfully")
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\ayush\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# YOLO Imported Successfully

# %% [markdown]
# ## Observation
#
# The YOLOv8 library has been installed successfully and is ready for image detection and model training.
